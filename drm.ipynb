# %%
import pandas as pd
df = pd.read_csv("211210-DRM-total.csv")
metal_df = df.iloc[:,2:25]

# %%
metal_mean = metal_df.describe().iloc[1,:]

# %%
metal_mean.sort_values(ascending=False)
# Out:
# Ni    5.479145
# Co    1.034689
# La    0.313515
# Ce    0.146195
# Pt    0.119445
# Ag    0.118615
# K     0.077556
# Zr    0.048902
# Mg    0.040286
# Rh    0.036898
# Ru    0.036831
# Cu    0.017265
# Fe    0.016825
# Mn    0.016757
# Pr    0.014489
# Pd    0.013829
# Sr    0.013033
# Ca    0.012099
# Y     0.011848
# Ba    0.009096
# Ir    0.008125
# Au    0.001016
# Li    0.001016
# Name: mean, dtype: float64
